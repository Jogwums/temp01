# %% [markdown]
# # Working with Opencv for image handling and processing

# %%
import cv2
import numpy as np 
import matplotlib.pyplot as plt

print('ready')
# Out:
# ready

# %%
url = 'C:/Users/PC/Pictures/HOTBackground.jpeg'
hot=cv2.imread(url,0)
print(hot)
# Out:
# [[109 109 109 ... 142 121 223]
#  [ 25  25  25 ...  37  36 158]
#  [ 30  30  30 ...  27  36 176]
#  ...
#  [ 27  27  27 ...  26  29 175]
#  [ 27  27  27 ...  26  29 175]
#  [ 27  27  27 ...  26  29 175]]

# %%
# image properties 
print(hot.shape)
# Out:
# (576, 1024)

# %%
# image data type
print(hot.dtype)
# Out:
# uint8

# %%
# show image with matplotlib
plt.imshow(hot)

# %%
# image was read as grayscale but it's not showing grayscale

# this is because matplotlib imshow has it's own default cmap settings

# %%
# set cmap to grayscale for proper rendering 

plt.imshow(hot, cmap='gray')
